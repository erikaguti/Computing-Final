# %%
from PopularityContest.Model.best_model import *
from PopularityContest.Model.feature1 import *
from PopularityContest.Model.feature2 import *
from PopularityContest.Model.feature3 import *
from PopularityContest.Model.split import *
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("~/Documents/GitHub/Computing-Final/PopularityContest/Load/songfeatures.csv").select_dtypes("number")
data.head(5)
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.887   0.234    9   -14.520     1       0.1780
# 1           1         0.751   0.761   11    -4.113     0       0.1500
# 2           2         0.835   0.679    7    -5.329     0       0.0364
# 3           3         0.901   0.589    1    -6.713     0       0.2890
# 4           4         0.621   0.782    2    -5.548     1       0.0440
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.11100          0.670000    0.1300    0.197  140.020       196800
# 1       0.25100          0.000238    0.0991    0.553   92.032       151325
# 2       0.58300          0.000002    0.2180    0.850  124.980       162638
# 3       0.00302          0.000237    0.0992    0.399   98.002       196600
# 4       0.01250          0.033000    0.2300    0.550  128.033       198938
#
#    time_signature  Top50
# 0               4      1
# 1               4      1
# ...

# %%
data = feature1(data)
data.head(5)
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.887   0.234    9   -14.520     1       0.1780
# 1           1         0.751   0.761   11    -4.113     0       0.1500
# 2           2         0.835   0.679    7    -5.329     0       0.0364
# 3           3         0.901   0.589    1    -6.713     0       0.2890
# 4           4         0.621   0.782    2    -5.548     1       0.0440
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.11100          0.670000    0.1300    0.197  140.020       196800
# 1       0.25100          0.000238    0.0991    0.553   92.032       151325
# 2       0.58300          0.000002    0.2180    0.850  124.980       162638
# 3       0.00302          0.000237    0.0992    0.399   98.002       196600
# 4       0.01250          0.033000    0.2300    0.550  128.033       198938
#
#    time_signature  Top50  happy
# 0               4      1      0
# ...

# %%
data = genre(data)
data.head(5)
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.887   0.234    9   -14.520     1       0.1780
# 1           1         0.751   0.761   11    -4.113     0       0.1500
# 2           2         0.835   0.679    7    -5.329     0       0.0364
# 3           3         0.901   0.589    1    -6.713     0       0.2890
# 4           4         0.621   0.782    2    -5.548     1       0.0440
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0       0.11100          0.670000    0.1300    0.197  140.020       196800
# 1       0.25100          0.000238    0.0991    0.553   92.032       151325
# 2       0.58300          0.000002    0.2180    0.850  124.980       162638
# 3       0.00302          0.000237    0.0992    0.399   98.002       196600
# 4       0.01250          0.033000    0.2300    0.550  128.033       198938
#
#    time_signature  Top50  happy  HipHop  Reggaeton  Pop  House/Electro/Techno
# ...

# %%
data = time(data, "seconds")
data.head(5)
# Out:
#    Unnamed: 0  danceability  energy  key  loudness  mode  speechiness  \
# 0           0         0.887   0.234    9   -14.520     1       0.1780
# 1           1         0.751   0.761   11    -4.113     0       0.1500
# 2           2         0.835   0.679    7    -5.329     0       0.0364
# 3           3         0.901   0.589    1    -6.713     0       0.2890
# 4           4         0.621   0.782    2    -5.548     1       0.0440
#
#    acousticness  instrumentalness  liveness  valence    tempo  time_signature  \
# 0       0.11100          0.670000    0.1300    0.197  140.020               4
# 1       0.25100          0.000238    0.0991    0.553   92.032               4
# 2       0.58300          0.000002    0.2180    0.850  124.980               4
# 3       0.00302          0.000237    0.0992    0.399   98.002               4
# 4       0.01250          0.033000    0.2300    0.550  128.033               4
#
#    Top50  happy  HipHop  Reggaeton  Pop  House/Electro/Techno  duration_s
# ...

# %%
X_train, X_test, y_train, y_test = tt_split(data, "Top50")
X_test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15812\2524585832.py in <module>
# ----> 1 X_train, X_test, y_train, y_test = tt_split(data, "Top50")
#       2 X_test
#
# NameError: name 'tt_split' is not defined
